# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %% [markdown]
# # Basic Plotting

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000,4), index=ts.index, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.785599 -0.086289  0.401385 -0.478179
# 2000-01-02 -1.127348  1.252399 -0.041392 -1.110473
# 2000-01-03 -1.202696 -2.002858 -0.549255 -0.537185
# 2000-01-04 -0.506900 -0.103743  0.517790  0.837541
# 2000-01-05  0.704154 -0.173239 -0.630017 -0.701699
# 2000-01-06 -0.931174  0.532287  0.755047 -0.132847
# 2000-01-07 -1.046988 -2.706358 -0.754386 -0.736117
# 2000-01-08 -1.186389  1.182862  1.030403  0.390181
# 2000-01-09  2.358561 -0.016512  0.667747 -0.457211
# 2000-01-10  0.160116  2.029563 -2.110916 -0.082355
# 2000-01-11  0.428793 -1.420946 -2.036361 -0.544104
# 2000-01-12 -0.450957 -0.677233  1.143725  0.116424
# 2000-01-13  0.291971  0.558775 -0.366088 -0.096706
# 2000-01-14  0.885485  0.438880  0.003877  0.879414
# 2000-01-15  0.638645  0.533607  1.058406  0.757331
# 2000-01-16  0.349413 -0.096951  0.144462 -0.901109
# 2000-01-17  2.202217  0.717018  0.615082 -0.273988
# ...

# %%
n_groups = 5
means_men = (20, 35, 30, 35, 27)
std_men = (2, 3, 4, 1, 2)
means_women = (25, 32, 34, 20, 25)
std_women = (3, 5, 2, 3, 3)

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = plt.bar(index, means_men, bar_width,
                 alpha=opacity,
                 color='b',
                 yerr=std_men,
                 error_kw=error_config,
                 label='Men')

rects2 = plt.bar(index + bar_width, means_women, bar_width,
                 alpha=opacity,
                 color='r',
                 yerr=std_women,
                 error_kw=error_config,
                 label='Women')

plt.xlabel('Group')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D', 'E'))
plt.legend()

plt.tight_layout()

# %% [markdown]
# # Stacked Barchart

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, color='r', yerr=menStd)
p2 = plt.bar(ind, womenMeans, width, color='y',
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind + width/2., ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

# %% [markdown]
# # Stem Plot
# 이산 확률 함수나 자기상관관계(auto-correlation)를 묘사할 때 사용
# - http://matplotlib.org/1.5.1/api/pyplot_api.html#matplotlib.pyplot.stem
#
# <br>
# 이산(discrete) 확률 분포
# - 베르누이 분포 : 가장 기본적인 이산 확률 분포. ex) 불량,합격
# - 이항 분포 (binominal distribution)
#
# 연속확률분포
# - 균등분포, 정규분포, 지수분포, 감마분포, 베타분포, t분포, 카이제곱분포, F분포 등

# %%
x = np.linspace(0.1, 2*np.pi, 10)
markerline, stemlines, baseline = plt.stem(x, np.cos(x), '-.')
plt.setp(markerline, 'markerfacecolor', 'b')
plt.setp(baseline, 'color', 'r', 'linewidth', 2);

# %% [markdown]
# # Pychart

# %% [markdown]
# - Compare with values of each category
# - http://matplotlib.org/1.5.1/api/pyplot_api.html#matplotlib.pyplot.pie

# %%
labels = u'Female', u'Male', u'Unknown'
sizes = [45,35,20]
colors = ['yellowgreen', 'gold', 'lightskyblue']
explode = (0.1,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
# Out:
# (-1.1236953934619642,
#  1.0154185543584302,
#  -1.0154185644953777,
#  1.0156434502029854)
